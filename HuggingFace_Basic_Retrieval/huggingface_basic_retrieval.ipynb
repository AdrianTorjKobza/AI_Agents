# %%
# !pip install smolagents -U
# !pip install ddgs
# !pip install langchain-community
# !pip install rank_bm25

# %%
#  Login to the Hugging Face Hub to have access to the Inference API.
from huggingface_hub import notebook_login

notebook_login()

# %%
# Basic Retrieval with DuckDuckGo.
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# Initialize the search tool.
search_tool = DuckDuckGoSearchTool()

model = InferenceClientModel()

# Create and run the agent.
agent = CodeAgent(
    model=model,
    tools=[search_tool],
)

response = agent.run(
    "Search for 80's themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for 80's themed party ideas, including decorations, entertainment, and catering.                         │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   decorations_ideas = web_search(query="80s party decorations ideas")
#   entertainment_ideas = web_search(query="80s party entertainment ideas")
#   catering_ideas = web_search(query="80s party catering ideas")
#
#   print("Decorations Ideas:\n", decorations_ideas)
#   print("\nEntertainment Ideas:\n", entertainment_ideas)
#   print("\nCatering Ideas:\n", catering_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Decorations Ideas:
#  ## Search Results
#
# [Windy City Novelties 80s Theme Party Decorations, Supplies, Favors, &
# Accessories](https://www.windycitynovelties.com/party-themes/decades/80-s-theme.html)
# Decorate your '80s home in wall cutouts, scene setters and hanging decorations . Add some table flair with '80s
# themed runners, dinnerware, and centerpieces. Invite fellow 1980s enthusiasts with custom invitations and '80s
# theme party favors.
#
# [Pinterest 310 Best 80's Party ideas](https://www.pinterest.com/6osborne/80s-party/)
# 1980s Theme Party Ideas 80s Prom · Cassette Tape Decorations · 80s Arts And Crafts · Decades Decorations Ideas ·
# 80s Crafts Ideas · 80s Theme Gala · 80's Decorations · Diy 80s Decor · Splattering Neon Paint On Cassette Tapes. I
# Found It Easiest To Dip My 0C ·
#
# [Bulk Party Supplies 80's Party Supplies & Decorations - Bulk Prices for Retro Bash
# Perfection](https://www.bulkpartysupplies.com/collections/80s-party-theme)
# 2 weeks ago - Kick off the celebration with our "Back To The 80's" Party Sign, measuring 15.5" x 24", and set the
# scene with our Awesome 80's Cutouts featuring iconic symbols of the era. Let guests strike a pose with our Break
# Dancer Party Props and Metallic 80's Icon Silhouettes, or groove to the beat with our Boom Box Stand-Up Decoration.
#
# [PartySlate Break Out Your Neon & Spandex for These 80s Theme Party Ideas -
# PartySlate](https://www.partyslate.com/best-of/80s-theme-party-ideas)
# February 6, 2024 - Travel back in time with 19 of the best 80s theme party ideas we’ve seen on PartySlate, and
# discover the vendors behind each event.
#
# [Amazon Amazon.com: Totally 80s Party
# Decorations](https://www.amazon.com/totally-80s-party-decorations/s?k=totally+80s+party+decorations)
# Check each product page for other buying options. Price and other details may vary based on product size and color
# · Tiamon 41pc 80s Party Decoration Set - I Love 80s Banner with 40 Multicolored Balloons, Retro Boombox Background
# for Hip Hop Party, Photo Booth Props & Supplies (70.8 x 15.7 ...
#
# [Southernhomeandhospitality Totally Tubular 80s Party Guide: Decor, Food, Costumes, Activities &
# Music](https://southernhomeandhospitality.com/80s-party-ideas/)
# August 13, 2025 - Outside on the back patio table, I strung out a hot pink tinsel curtain, and tossed on it some
# 80s trivia cards and more 80s party favors. And those shimmery CDs made a perfect candleholder to reflect the light
# with some hot glue and painted wine corks. If you’d like to see other theme decorations for this annual party we
# host, here are a couple: “Throw the Ultimate Margaritaville Party” and “PAR-TEE Time: Ideas for a Golf Themed
# Party“.
#
# [Walmart 80s Party Supplies in Party & Occasions -
# Walmart.com](https://www.walmart.com/browse/party-occasions/80s-party-supplies/2637_3351945)
# $12.99PIXHOTUL Novelty Boom Favors Boxes - 80s Theme Boom Box 80’s Theme Retro Decorations 1980s Hip Hop Party
# Supplies Table Centerpieces for Retro Party, Hip Hop Party, 80s Theme party
#
# [Balloons Online Ideas for an Awesome 80s Theme
# Party](https://balloons.online/blog/ideas-for-a-awesome-80s-theme-party/)
# January 25, 2024 - Decorate the walls with posters of the legendary idols of the 80s: Madonna, ABBA, Michael
# Jackson, and others. Clippings and posts from old magazines are also suitable. The 80s were the years of wild neon
# lights and bold colors. To immerse yourself in the party of the 80s, neon lighting will undeniably do the trick.
# Hang 80s album covers or vinyl records. It will add some entourage to your party. A cool idea for party lighting is
# the use of lamps that periodically change their color.
#
# [Chica and Jo 80s Birthday Party Planning Ideas | Chica and
# Jo](https://www.chicaandjo.com/80s-themed-birthday-party-ideas/)
# At one party, we decided to welcome our guests with a real wow moment in the form of a Pac-Man balloon arch. With a
# simple balloon arch kit and a bunch of black balloons, we built a big arch over the entry space. Then we attached a
# giant Pac-Man and some ghosts that we cut out of poster board. When we added tiny white balloons to be the dots, we
# knew we had a winning piece of 80s decor.
#
# [Jen Naye Herrmann Hosting a Joint-themed 30th Birthday 'Party Like it’s
# 1987'](https://www.jennaye.com/blog/2017-6-13-party-like-its-1987)
# February 12, 2024 - This versatile decor piece, found on Hostess with the Mostess, adds a touch of the '80s to
# doorways and creates a dynamic visual experience. Channel the MTV era with a sweets table featuring an astronaut
# cake reminiscent of OKC Sweets' creation. This nod to the pinnacle of '80s culture captures the essence of the
# decade's fascination with outer space and music television. I found so many great ideas when it came to cakes that
# it was hard to pick just one.
#
# Entertainment Ideas:
#  ## Search Results
#
# [20 Rad 80's Party Ideas for an Epic Throwback Celebration](https://captionsgenius.com/80s-party-ideas/)
# Throwing an 80s party ? Prepare yourself for bold colors, cassette tapes, arcade vibes, and funky fashion. From
# neon decor to nostalgic snacks, this guide covers everything, DIY decorations, themed outfits, music playlists, and
# entertainment ideas .
#
# [18 Bodacious Ideas for a Totally 80s Theme Party (2025)](https://www.peerspace.com/resources/80s-party-ideas/)
# Organizing a party isn't always easy, especially when it's a theme party—there's decor, costumes, food and drink,
# venue rental, and more to consider. But if you're in need of some top-notch 80s party ideas , then we've got you
# covered with a collection of creative suggestions that you aren't likely to find elsewhere.
#
# [The Ultimate Guide to Hosting a Totally Tubular 80s
# Party](https://southernhomeandhospitality.com/80s-party-ideas/)
# Hosting an 80s party ? This guide has everything you need: neon décor ideas , food ideas , costume tips, the
# perfect playlist, retro games, and nostalgic favors. Get ready to party like it's 1989!
#
# [What Can You Do At A 1980s Party? A Retro Guide to
# Fun!](https://brilliantio.com/what-can-you-do-at-a-1980s-party/)
# To make your party tubular, consider these 80s party ideas : Set up a retro arcade: Bring in classic 80s games like
# Pac-Man, Donkey Kong, and Space Invaders for guests to enjoy. Create a DIY photo booth: Deck out a corner of the
# room with 80s props such as inflatable guitars, funky sunglasses, and big-haired wigs for guests to snap gnarly
# pictures.
#
# [Everything You Need for an 80s Theme Party - The Bash](https://www.thebash.com/articles/80s-theme-party)
# An 80s themed party is perfect for milestone birthdays, bachelorette parties, or just a good old celebration with
# friends and family. From music to outfits, and everything in between, these 80s party ideas are sure to help you
# plan an event your guests will never forget.
#
# [21 Epic 80s Theme Party Ideas for a Totally Rad
# Experience](https://bysandyvilce.com/21-epic-80s-theme-party-ideas-for-a-totally-rad-experience/)
# From party themes to games, step back in time with these totally rad 80s theme party ideas . Whether you're
# planning a birthday bash, a costume party , or just want an excuse to rock some cute retro outfits; grab your
# scrunchies and shoulder pads and party like it's the 1980s.
#
# [Ultimate List of 80s Party Ideas and Themes - Encore
# Blog](https://encoremusicians.com/blog/ultimate-80s-party-theme-guide/)
# Throwing an 80s themed party ? Check out this list of awesome 80s party ideas and themes to make your event a
# totally rad blast from the past!
#
# [18 Totally Bodacious Ideas For Your 80s Theme Party](https://www.bandsforhire.net/blog/80s-themed-party)
# 18 Totally Bodacious Ideas For Your 80s Theme Party Throw the ultimate 80s bash with our top party tips and ideas .
#
# [Full Guide on Throwing the Most Rad 80s Party - Buttercream
# Parties](https://buttercreamparties.com/full-guide-80s-party/)
# How to throw the most rad 80s party including 80s party food, 80s party outfits, 80s party songs, 80s party decor,
# and more!
#
# [17+ Epic '80s Party Ideas to Transport You Back in Time!](https://laughlore.com/80s-party-ideas/)
# The '80s were a time of neon colors, bold styles, and unforgettable music. If you're looking to throw an epic '80s
# party , you're in the right place! From vibrant decor to classic arcade games, this list of 17+ '80s party ideas
# will have your guests feeling like they've traveled back in time.
#
# Catering Ideas:
#  ## Search Results
#
# [80s Themed Party Ideas | Retro Party
# Entertainment](https://www.addtoevent.co.uk/themes/80s-retro-themed-party-ideas)
# Whether you're planning a birthday bash or a corporate event, our collection of ideas will help you throw the best
# 80s party with nostalgic flair.
#
# [Best Party Catering- Updated For 2022](https://partyideas4u.com/party-decor/best-party-catering/)
# Additionally, for such events, you will want a party catering near you with on-premises services to discuss your
# ideas and ensure that you both are ...
#
# [80's Theme Party](https://www.punchbowl.com/p/80-s-theme-party-for-the-ages)
# ... some birthday fun at the same time with an 80s party for a teen! Pay tribute to the 80s with a righteous 80s
# theme party ! Plan 80s party theme ideas ...
#
# [Throw a themed party with Hog Roast Bishop's
# Castle](https://spittingpigshropshire.co.uk/throw-a-themed-party-with-hog-roast-bishops-castle-catering/)
# Instead, a theme can help you to come up with party games and catering ideas . ... have created a list of great
# party themes and ideas for catering ...
#
# [Totally Awesome Ideas for an ‘80s-Themed Picnic |
# Tasty](https://tastycatering.com/totally-awesome-ideas-for-an-80s-themed-picnic/)
# Fun ‘ 80s fact: After designing what he called the “magic cube,” Erno Rubik had no idea how to solve the puzzle he
# created.
#
# [Top 80s Party Food Ideas For Your Birthday](https://bitefull.com/top-80s-party-food-ideas-for-your-birthday/)
# When it comes to 80s party food ideas , nothing beats spinach dip pastries! Whether you ’ re using store-bought
# dough or making your own from ...
#
# [Rocking your next party in style! - Jacquie's
# Gourmet](https://www.jacquies.net/2019/01/22/rocking-your-next-party-in-style/)
# appetizers , Caterer Indianapolis , Christmas parties , Corporate Catering , Events , gourmet , holiday weddings in
# Indianapolis , Jacquie's Gourmet ...
#
# [Enjoy The Fun With These Catered Corporate Party Ideas -
# Supper](https://supperclubyvr.com/enjoy-the-fun-catered-corporate-party-ideas/)
# Supper Club YVR brings you the best catered Corporate Party Ideas , it will turn your events into a bomb of
# success.
#
# [25 Gnarly 80s Party Ideas for
# Adults](https://thebestnest.co/holidays-and-events/parties/80s-party-ideas-for-adults/)
# Trivia is probably one of the easiest 80s party ideas for adults because it ’ s not just fun, it ’ s usually
# something you can do all ...
#
# [Boosting Team Morale with a Memorable Corporate Event
# Featuring](https://www.articleted.com/article/862610/37444/Boosting-Team-Morale-with-a-Memorable-Corporate-Event-Fe
# aturing-Spit-Roast-Catering)
# Everyone loves to get an extra dose of nostalgia, especially of the radical parties , awesome games and the
# righteous tunes of the 80s .
#
# Out: None
# [Step 1: Duration 10.25 seconds| Input tokens: 2,093 | Output tokens: 150]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import re
#
#   # Extracting decoration ideas
#   decoration_pattern = re.compile(r'Decorate.*?\.(?=\s*$|\n\s*\n)', re.DOTALL)
#   decoration_matches = decoration_pattern.findall(decorations_ideas)
#   decoration_summary = "\n".join(decoration_matches)
#
#   # Extracting entertainment ideas
#   entertainment_pattern = re.compile(r'Throw.*?\.(?=\s*$|\n\s*\n)', re.DOTALL)
#   entertainment_matches = entertainment_pattern.findall(entertainment_ideas)
#   entertainment_summary = "\n".join(entertainment_matches)
#
#   # Extracting catering food ideas
#   catering_food_pattern = re.compile(r'80s party food ideas.*?\.(?=\s*$|\n\s*\n)', re.DOTALL)
#   catering_food_matches = catering_food_pattern.findall(catering_ideas)
#   catering_summary = "\n".join(catering_food_matches)
#
#   print("Decorations Summary:\n", decoration_summary)
#   print("\nEntertainment Summary:\n", entertainment_summary)
#   print("\nCatering Summary:\n", catering_summary)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Decorations Summary:
#  Decorate your '80s home in wall cutouts, scene setters and hanging decorations . Add some table flair with '80s
# themed runners, dinnerware, and centerpieces. Invite fellow 1980s enthusiasts with custom invitations and '80s
# theme party favors.
# Decorate the walls with posters of the legendary idols of the 80s: Madonna, ABBA, Michael Jackson, and others.
# Clippings and posts from old magazines are also suitable. The 80s were the years of wild neon lights and bold
# colors. To immerse yourself in the party of the 80s, neon lighting will undeniably do the trick. Hang 80s album
# covers or vinyl records. It will add some entourage to your party. A cool idea for party lighting is the use of
# lamps that periodically change their color.
#
# Entertainment Summary:
#  Throwback Celebration](https://captionsgenius.com/80s-party-ideas/)
# Throwing an 80s party ? Prepare yourself for bold colors, cassette tapes, arcade vibes, and funky fashion. From
# neon decor to nostalgic snacks, this guide covers everything, DIY decorations, themed outfits, music playlists, and
# entertainment ideas .
# Throwing an 80s themed party ? Check out this list of awesome 80s party ideas and themes to make your event a
# totally rad blast from the past!
#
# [18 Totally Bodacious Ideas For Your 80s Theme Party](https://www.bandsforhire.net/blog/80s-themed-party)
# 18 Totally Bodacious Ideas For Your 80s Theme Party Throw the ultimate 80s bash with our top party tips and ideas .
# Throwing the Most Rad 80s Party - Buttercream Parties](https://buttercreamparties.com/full-guide-80s-party/)
# How to throw the most rad 80s party including 80s party food, 80s party outfits, 80s party songs, 80s party decor,
# and more!
#
# [17+ Epic '80s Party Ideas to Transport You Back in Time!](https://laughlore.com/80s-party-ideas/)
# The '80s were a time of neon colors, bold styles, and unforgettable music. If you're looking to throw an epic '80s
# party , you're in the right place! From vibrant decor to classic arcade games, this list of 17+ '80s party ideas
# will have your guests feeling like they've traveled back in time.
#
# Catering Summary:
#  80s party food ideas , nothing beats spinach dip pastries! Whether you ’ re using store-bought dough or making
# your own from ...
#
# Out: None
# [Step 2: Duration 11.35 seconds| Input tokens: 7,469 | Output tokens: 417]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Consolidating decoration ideas
#   decoration_ideas = """
#   - Wall cutouts, scene setters, and hanging decorations.
#   - Table runners, dinnerware, and centerpieces.
#   - Custom invitations and '80s theme party favors.
#   - Posters of legendary 80s idols (e. g., Madonna, ABBA, Michael Jackson).
#   - Clippings and posts from old magazines.
#   - Neon lights and colorful lamps.
#   - Album covers or vinyl records hung around.
#   """
#
#   # Consolidating entertainment ideas
#   entertainment_ideas = """
#   - Classic 80s music playlists.
#   - Retro arcade games (e. g., Pac-Man, Donkey Kong, Space Invaders).
#   - DIY photo booth with 80s props (inflatable guitars, sunglasses, big-haired wigs).
#   - Nostalgic outfits and costumes.
#   """
#
#   # Consolidating catering ideas
#   catering_ideas = """
#   - Spinach dip pastries.
#   - Classic 80s dishes and snacks.
#   - Vintage sodas and punch.
#   """
#
#   # Creating a comprehensive summary for the 80's themed party
#   party_plan = f"""
#   ### 80's Themed Party Plan
#
#   #### Decorations:
#   {decoration_ideas}
#
#   #### Entertainment:
#   {entertainment_ideas}
#
#   #### Catering:
#   {catering_ideas}
#   """
#
#   final_answer(party_plan)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer:
# ### 80's Themed Party Plan
#
# #### Decorations:
#
# - Wall cutouts, scene setters, and hanging decorations.
# - Table runners, dinnerware, and centerpieces.
# - Custom invitations and '80s theme party favors.
# - Posters of legendary 80s idols (e. g., Madonna, ABBA, Michael Jackson).
# - Clippings and posts from old magazines.
# - Neon lights and colorful lamps.
# - Album covers or vinyl records hung around.
#
#
# #### Entertainment:
#
# - Classic 80s music playlists.
# - Retro arcade games (e. g., Pac-Man, Donkey Kong, Space Invaders).
# - DIY photo booth with 80s props (inflatable guitars, sunglasses, big-haired wigs).
# - Nostalgic outfits and costumes.
#
#
# #### Catering:
#
# - Spinach dip pastries.
# - Classic 80s dishes and snacks.
# - Vintage sodas and punch.
# [Step 3: Duration 13.78 seconds| Input tokens: 13,995 | Output tokens: 737]
# ### 80's Themed Party Plan
#
# #### Decorations:
#
# - Wall cutouts, scene setters, and hanging decorations.
# - Table runners, dinnerware, and centerpieces.
# - Custom invitations and '80s theme party favors.
# - Posters of legendary 80s idols (e. g., Madonna, ABBA, Michael Jackson).
# - Clippings and posts from old magazines.
# - Neon lights and colorful lamps.
# - Album covers or vinyl records hung around.
#
#
# #### Entertainment:
#
# - Classic 80s music playlists.
# - Retro arcade games (e. g., Pac-Man, Donkey Kong, Space Invaders).
# - DIY photo booth with 80s props (inflatable guitars, sunglasses, big-haired wigs).
# - Nostalgic outfits and costumes.
#
#
# #### Catering:
#
# - Spinach dip pastries.
# - Classic 80s dishes and snacks.
# - Vintage sodas and punch.

# %%
# BM25 retriever to search the knowledge base and return the top results.

from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Adrian’s 80's-themed party at Dracula Castle."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or 80's themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning.
party_ideas = [
    {"text": "An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for 80's music fans.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after 80's movie stars.", "source": "Catering Ideas"},
    {"text": "Decorate with iconic 80's movies and games posters.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in 80's movies simulations.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search.
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)

docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool.
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

# Initialize the agent.
agent = CodeAgent(tools=[party_planning_retriever], model=InferenceClientModel())

response = agent.run(
    "Find ideas for a luxury 80's-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury 80's-themed party, including entertainment, catering, and decoration options.           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-Coder-32B-Instruct ────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="80's-themed party entertainment")
#   catering_ideas = party_planning_retriever(query="80's-themed party catering")
#   decoration_ideas = party_planning_retriever(query="80's-themed party decorations")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 1: Duration 6.47 seconds| Input tokens: 2,113 | Output tokens: 146]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="luxury 80's-themed party entertainment options")
#   catering_ideas = party_planning_retriever(query="luxury 80's-themed party catering options")
#   decoration_ideas = party_planning_retriever(query="luxury 80's-themed party decoration options")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 2: Duration 6.45 seconds| Input tokens: 4,895 | Output tokens: 293]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="unique luxury 80's-themed party entertainment
#   suggestions")
#   catering_ideas = party_planning_retriever(query="exclusive luxury 80's-themed party catering menu ideas")
#   decoration_ideas = party_planning_retriever(query="distinct luxury 80's-themed party decoration concepts")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 3: Duration 6.89 seconds| Input tokens: 8,359 | Output tokens: 450]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 4 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="luxury 80's-themed party live band options")
#   catering_ideas = party_planning_retriever(query="high-end 80's-themed party gourmet food suggestions")
#   decoration_ideas = party_planning_retriever(query="lavish 80's-themed party chandelier and disco ball ideas")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 4: Duration 7.14 seconds| Input tokens: 12,516 | Output tokens: 607]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 5 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="luxury 80's-themed party retro lounge band")
#   catering_ideas = party_planning_retriever(query="high-end 80's-themed party catered buffet with neon
#   cocktails")
#   decoration_ideas = party_planning_retriever(query="lavish 80's-themed party decor with mirrored balls and neon
#   signs")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 1 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 5: Duration 7.34 seconds| Input tokens: 17,371 | Output tokens: 763]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 6 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   entertainment_ideas = party_planning_retriever(query="retro lounge band options for high-end parties")
#   catering_ideas = party_planning_retriever(query="gourmet food suggestions with neon-themed cocktails")
#   decoration_ideas = party_planning_retriever(query="lavish decor options with mirrored balls and neon signs")
#
#   print("Entertainment Ideas:", entertainment_ideas)
#   print("Catering Ideas:", catering_ideas)
#   print("Decoration Ideas:", decoration_ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Entertainment Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
# Catering Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 2 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
# Decoration Ideas:
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# Decorate with iconic 80's movies and games posters.
#
# ===== Idea 1 =====
# An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.
#
# ===== Idea 2 =====
# Interactive experiences with VR where guests can engage in 80's movies simulations.
#
# ===== Idea 3 =====
# For catering, serve dishes named after 80's movie stars.
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for 80's music fans.
#
# Out: None
# [Step 6: Duration 7.43 seconds| Input tokens: 22,927 | Output tokens: 907]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 7 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   unique_entertainment_ideas = [
#       "Hire a professional DJ who can play themed music for 80's music fans."
#   ]
#
#   unique_catering_ideas = [
#       "Serve dishes named after 80's movie stars."
#   ]
#
#   unique_decoration_ideas = [
#       "Decorate with iconic 80's movies and games posters.",
#       "An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.",
#       "Interactive experiences with VR where guests can engage in 80's movies simulations."
#   ]
#
#   response = {
#       "Entertainment": unique_entertainment_ideas,
#       "Catering": unique_catering_ideas,
#       "Decoration": unique_decoration_ideas
#   }
#
#   final_answer(response)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: {'Entertainment': ["Hire a professional DJ who can play themed music for 80's music fans."],
# 'Catering': ["Serve dishes named after 80's movie stars."], 'Decoration': ["Decorate with iconic 80's movies and
# games posters.", "An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.",
# "Interactive experiences with VR where guests can engage in 80's movies simulations."]}
# [Step 7: Duration 15.53 seconds| Input tokens: 29,156 | Output tokens: 1,251]
# {'Entertainment': ["Hire a professional DJ who can play themed music for 80's music fans."], 'Catering': ["Serve dishes named after 80's movie stars."], 'Decoration': ["Decorate with iconic 80's movies and games posters.", "An 80's-themed masquerade ball with luxury decor, including violet accents and velvet curtains.", "Interactive experiences with VR where guests can engage in 80's movies simulations."]}
